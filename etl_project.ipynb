# %% [markdown]
# # ETL Project

# %%
# Dependencies
import pandas as pd
import numpy as np

import string
import json
import requests
import time

from api_keys import g_api_key, isbn_api_key, goodreads_api_key, username, password
from sqlalchemy import create_engine

# %% [markdown]
# ## New York Times Bestsellers 2011-2018 CSV
# Source: https://data.world/typhon/new-york-times-bestsellers-from-2011-to-2018

# %% [markdown]
# ### Store CSV into Dataframe

# %%
nyt_weeks_df = pd.read_csv("data/nyt_weeks_2011_2018.csv", encoding='cp1252')
nyt_weeks_df
# Out:
#           publisher  dagger  \
# 0         Riverhead       0
# 1          Scribner       0
# 2           Vintage       0
# 3      St. Martin's       0
# 4     Penguin Group       0
# ...             ...     ...
# 2244    Tom Doherty       0
# 2245  Penguin Group       0
# 2246   Random House       0
# 2247  Penguin Group       0
# 2248  Penguin Group       0
#
#                                        book_review_link  \
# 0     https://www.nytimes.com/2015/01/05/books/the-g...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     https://www.nytimes.com/2009/02/19/books/19mas...
# ...                                                 ...
# 2244                                                NaN
# 2245                                                NaN
# 2246                                                NaN
# 2247                                                NaN
# 2248                                                NaN
#
#                                    author primary_isbn10  price  \
# 0                           Paula Hawkins     1594634025      0
# 1                           Anthony Doerr     1501173219      0
# 2                               E L James      525431888      0
# 3                          Kristin Hannah     1466850604      0
# 4                        Kathryn Stockett     1440697663      0
# ...                                   ...            ...    ...
# 2244  Robert Jordan and Brandon Sanderson     1429960639      0
# 2245                       Charles Portis     159020459X      0
# 2246                   Karen Marie Moning     044033974X      0
# 2247                         Nalini Singh           None      0
# 2248                         Robert Crais           None      0
#
#      primary_isbn13                                 sunday_review_link  \
# 0          9.78E+12  https://www.nytimes.com/2015/02/01/books/revie...
# 1          9.78E+12  https://www.nytimes.com/2014/05/11/books/revie...
# 2          9.78E+12                                                NaN
# 3          9.78E+12                                                NaN
# 4          9.78E+12                                                NaN
# ...             ...                                                ...
# 2244       9.78E+12                                                NaN
# 2245       9.78E+12                                                NaN
# 2246       9.78E+12                                                NaN
# 2247       9.78E+12                                                NaN
# 2248       9.78E+12                                                NaN
#
#             date first_chapter_link                             contributor  \
# 0      2/19/2017                NaN                        by Paula Hawkins
# 1       5/7/2017                NaN                        by Anthony Doerr
# 2       3/5/2017                NaN                          by E. L. James
# 3     10/29/2017                NaN                       by Kristin Hannah
# 4       4/8/2012                NaN                     by Kathryn Stockett
# ...          ...                ...                                     ...
# 2244   2/20/2011                NaN  by Robert Jordan and Brandon Sanderson
# 2245   2/20/2011                NaN                       by Charles Portis
# 2246   2/20/2011                NaN                   by Karen Marie Moning
# 2247   2/13/2011                NaN                         by Nalini Singh
# 2248   2/13/2011                NaN                         by Robert Crais
#
#                             title  age_group  weeks_on_list
# 0           THE GIRL ON THE TRAIN        NaN            102
# 1     ALL THE LIGHT WE CANNOT SEE        NaN             81
# 2             FIFTY SHADES DARKER        NaN             66
# 3                 THE NIGHTINGALE        NaN             63
# 4                        THE HELP        NaN             58
# ...                           ...        ...            ...
# 2244           TOWERS OF MIDNIGHT        NaN              0
# 2245                    TRUE GRIT        NaN              0
# 2246                  SHADOWFEVER        NaN              0
# 2247        ARCHANGELâ€™S CONSORT        NaN              0
# 2248                   THE SENTRY        NaN              0
#
# [2249 rows x 14 columns]

# %% [markdown]
# ### Data Cleaning

# %%
# Drop duplicates, if any
nyt_weeks_df = nyt_weeks_df.drop_duplicates()
nyt_weeks_df
# Out:
#           publisher  dagger  \
# 0         Riverhead       0
# 1          Scribner       0
# 2           Vintage       0
# 3      St. Martin's       0
# 4     Penguin Group       0
# ...             ...     ...
# 2244    Tom Doherty       0
# 2245  Penguin Group       0
# 2246   Random House       0
# 2247  Penguin Group       0
# 2248  Penguin Group       0
#
#                                        book_review_link  \
# 0     https://www.nytimes.com/2015/01/05/books/the-g...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     https://www.nytimes.com/2009/02/19/books/19mas...
# ...                                                 ...
# 2244                                                NaN
# 2245                                                NaN
# 2246                                                NaN
# 2247                                                NaN
# 2248                                                NaN
#
#                                    author primary_isbn10  price  \
# 0                           Paula Hawkins     1594634025      0
# 1                           Anthony Doerr     1501173219      0
# 2                               E L James      525431888      0
# 3                          Kristin Hannah     1466850604      0
# 4                        Kathryn Stockett     1440697663      0
# ...                                   ...            ...    ...
# 2244  Robert Jordan and Brandon Sanderson     1429960639      0
# 2245                       Charles Portis     159020459X      0
# 2246                   Karen Marie Moning     044033974X      0
# 2247                         Nalini Singh           None      0
# 2248                         Robert Crais           None      0
#
#      primary_isbn13                                 sunday_review_link  \
# 0          9.78E+12  https://www.nytimes.com/2015/02/01/books/revie...
# 1          9.78E+12  https://www.nytimes.com/2014/05/11/books/revie...
# 2          9.78E+12                                                NaN
# 3          9.78E+12                                                NaN
# 4          9.78E+12                                                NaN
# ...             ...                                                ...
# 2244       9.78E+12                                                NaN
# 2245       9.78E+12                                                NaN
# 2246       9.78E+12                                                NaN
# 2247       9.78E+12                                                NaN
# 2248       9.78E+12                                                NaN
#
#             date first_chapter_link                             contributor  \
# 0      2/19/2017                NaN                        by Paula Hawkins
# 1       5/7/2017                NaN                        by Anthony Doerr
# 2       3/5/2017                NaN                          by E. L. James
# 3     10/29/2017                NaN                       by Kristin Hannah
# 4       4/8/2012                NaN                     by Kathryn Stockett
# ...          ...                ...                                     ...
# 2244   2/20/2011                NaN  by Robert Jordan and Brandon Sanderson
# 2245   2/20/2011                NaN                       by Charles Portis
# 2246   2/20/2011                NaN                   by Karen Marie Moning
# 2247   2/13/2011                NaN                         by Nalini Singh
# 2248   2/13/2011                NaN                         by Robert Crais
#
#                             title  age_group  weeks_on_list
# 0           THE GIRL ON THE TRAIN        NaN            102
# 1     ALL THE LIGHT WE CANNOT SEE        NaN             81
# 2             FIFTY SHADES DARKER        NaN             66
# 3                 THE NIGHTINGALE        NaN             63
# 4                        THE HELP        NaN             58
# ...                           ...        ...            ...
# 2244           TOWERS OF MIDNIGHT        NaN              0
# 2245                    TRUE GRIT        NaN              0
# 2246                  SHADOWFEVER        NaN              0
# 2247        ARCHANGELâ€™S CONSORT        NaN              0
# 2248                   THE SENTRY        NaN              0
#
# [2249 rows x 14 columns]

# %%
# Select relevant columns 
nyt_weeks = nyt_weeks_df[["title", "author", "publisher", "date", "weeks_on_list"]]
nyt_weeks
# Out:
#                             title                               author  \
# 0           THE GIRL ON THE TRAIN                        Paula Hawkins
# 1     ALL THE LIGHT WE CANNOT SEE                        Anthony Doerr
# 2             FIFTY SHADES DARKER                            E L James
# 3                 THE NIGHTINGALE                       Kristin Hannah
# 4                        THE HELP                     Kathryn Stockett
# ...                           ...                                  ...
# 2244           TOWERS OF MIDNIGHT  Robert Jordan and Brandon Sanderson
# 2245                    TRUE GRIT                       Charles Portis
# 2246                  SHADOWFEVER                   Karen Marie Moning
# 2247        ARCHANGELâ€™S CONSORT                         Nalini Singh
# 2248                   THE SENTRY                         Robert Crais
#
#           publisher        date  weeks_on_list
# 0         Riverhead   2/19/2017            102
# 1          Scribner    5/7/2017             81
# 2           Vintage    3/5/2017             66
# 3      St. Martin's  10/29/2017             63
# 4     Penguin Group    4/8/2012             58
# ...             ...         ...            ...
# 2244    Tom Doherty   2/20/2011              0
# 2245  Penguin Group   2/20/2011              0
# 2246   Random House   2/20/2011              0
# 2247  Penguin Group   2/13/2011              0
# 2248  Penguin Group   2/13/2011              0
#
# [2249 rows x 5 columns]

# %%
# Replace â€™ with a single apostrophe
nyt_title_new = nyt_weeks.replace("â€™", "'", regex=True)
nyt_title_new
# Out:
#                             title                               author  \
# 0           THE GIRL ON THE TRAIN                        Paula Hawkins
# 1     ALL THE LIGHT WE CANNOT SEE                        Anthony Doerr
# 2             FIFTY SHADES DARKER                            E L James
# 3                 THE NIGHTINGALE                       Kristin Hannah
# 4                        THE HELP                     Kathryn Stockett
# ...                           ...                                  ...
# 2244           TOWERS OF MIDNIGHT  Robert Jordan and Brandon Sanderson
# 2245                    TRUE GRIT                       Charles Portis
# 2246                  SHADOWFEVER                   Karen Marie Moning
# 2247          ARCHANGEL'S CONSORT                         Nalini Singh
# 2248                   THE SENTRY                         Robert Crais
#
#           publisher        date  weeks_on_list
# 0         Riverhead   2/19/2017            102
# 1          Scribner    5/7/2017             81
# 2           Vintage    3/5/2017             66
# 3      St. Martin's  10/29/2017             63
# 4     Penguin Group    4/8/2012             58
# ...             ...         ...            ...
# 2244    Tom Doherty   2/20/2011              0
# 2245  Penguin Group   2/20/2011              0
# 2246   Random House   2/20/2011              0
# 2247  Penguin Group   2/13/2011              0
# 2248  Penguin Group   2/13/2011              0
#
# [2249 rows x 5 columns]

# %%
# Sort descending by weeks on the list 
nyt_title_new.sort_values(by=["weeks_on_list"], ascending=False, inplace=True)
nyt_title_new
# Out:
#                             title            author  \
# 0           THE GIRL ON THE TRAIN     Paula Hawkins
# 1     ALL THE LIGHT WE CANNOT SEE     Anthony Doerr
# 2             FIFTY SHADES DARKER         E L James
# 3                 THE NIGHTINGALE    Kristin Hannah
# 4                        THE HELP  Kathryn Stockett
# ...                           ...               ...
# 1681                   DEEP STORM     Lincoln Child
# 1682         FIFTY SHADES OF GREY         E L James
# 1683                RECKLESS LOVE      Kendall Ryan
# 1684                   ENDANGERED           C J Box
# 2248                   THE SENTRY      Robert Crais
#
#                              publisher        date  weeks_on_list
# 0                            Riverhead   2/19/2017            102
# 1                             Scribner    5/7/2017             81
# 2                              Vintage    3/5/2017             66
# 3                         St. Martin's  10/29/2017             63
# 4                        Penguin Group    4/8/2012             58
# ...                                ...         ...            ...
# 1681  Knopf Doubleday Publishing Group   4/12/2015              0
# 1682                           Vintage    4/5/2015              0
# 1683                      Kendall Ryan    4/5/2015              0
# 1684                            Putnam    4/5/2015              0
# 2248                     Penguin Group   2/13/2011              0
#
# [2249 rows x 5 columns]

# %%
# Look at NYT bestsellers on the list for 7 weeks or more (99 books)
nyt_title_new = nyt_title_new.loc[(nyt_title_new["weeks_on_list"] >= 7)]
nyt_title_new
# Out:
#                                    title             author      publisher  \
# 0                  THE GIRL ON THE TRAIN      Paula Hawkins      Riverhead
# 1            ALL THE LIGHT WE CANNOT SEE      Anthony Doerr       Scribner
# 2                    FIFTY SHADES DARKER          E L James        Vintage
# 3                        THE NIGHTINGALE     Kristin Hannah   St. Martin's
# 4                               THE HELP   Kathryn Stockett  Penguin Group
# ..                                   ...                ...            ...
# 86                              THE DROP   Michael Connelly  Little, Brown
# 85             THE WRONG SIDE OF GOODBYE   Michael Connelly  Little, Brown
# 84                         THE LATE SHOW   Michael Connelly  Little, Brown
# 83  THE GIRL WHO TAKES AN EYE FOR AN EYE  David Lagercrantz          Knopf
# 88                               REVIVAL       Stephen King       Scribner
#
#           date  weeks_on_list
# 0    2/19/2017            102
# 1     5/7/2017             81
# 2     3/5/2017             66
# 3   10/29/2017             63
# 4     4/8/2012             58
# ..         ...            ...
# 86   3/27/2016              7
# 85   1/15/2017              7
# 84  10/15/2017              7
# 83  11/12/2017              7
# 88   1/11/2015              7
#
# [99 rows x 5 columns]

# %%
# Converting title case with capwords to prevent capitalization of a letter after apostrophe
nyt_title_new["title_case"] = nyt_title_new["title"].apply(lambda x: string.capwords(x))
nyt_title_new
# Out:
# C:\Users\ama29\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                    title             author      publisher  \
# 0                  THE GIRL ON THE TRAIN      Paula Hawkins      Riverhead
# 1            ALL THE LIGHT WE CANNOT SEE      Anthony Doerr       Scribner
# 2                    FIFTY SHADES DARKER          E L James        Vintage
# 3                        THE NIGHTINGALE     Kristin Hannah   St. Martin's
# 4                               THE HELP   Kathryn Stockett  Penguin Group
# ..                                   ...                ...            ...
# 86                              THE DROP   Michael Connelly  Little, Brown
# 85             THE WRONG SIDE OF GOODBYE   Michael Connelly  Little, Brown
# 84                         THE LATE SHOW   Michael Connelly  Little, Brown
# 83  THE GIRL WHO TAKES AN EYE FOR AN EYE  David Lagercrantz          Knopf
# 88                               REVIVAL       Stephen King       Scribner
#
#           date  weeks_on_list                            title_case
# 0    2/19/2017            102                 The Girl On The Train
# 1     5/7/2017             81           All The Light We Cannot See
# 2     3/5/2017             66                   Fifty Shades Darker
# 3   10/29/2017             63                       The Nightingale
# 4     4/8/2012             58                              The Help
# ..         ...            ...                                   ...
# 86   3/27/2016              7                              The Drop
# 85   1/15/2017              7             The Wrong Side Of Goodbye
# 84  10/15/2017              7                         The Late Show
# 83  11/12/2017              7  The Girl Who Takes An Eye For An Eye
# 88   1/11/2015              7                               Revival
#
# [99 rows x 6 columns]

# %%
# Drop title column
nyt_title_new.drop(["title"], axis = 1, inplace=True)
nyt_title_new
# Out:
# C:\Users\ama29\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                author      publisher        date  weeks_on_list  \
# 0       Paula Hawkins      Riverhead   2/19/2017            102
# 1       Anthony Doerr       Scribner    5/7/2017             81
# 2           E L James        Vintage    3/5/2017             66
# 3      Kristin Hannah   St. Martin's  10/29/2017             63
# 4    Kathryn Stockett  Penguin Group    4/8/2012             58
# ..                ...            ...         ...            ...
# 86   Michael Connelly  Little, Brown   3/27/2016              7
# 85   Michael Connelly  Little, Brown   1/15/2017              7
# 84   Michael Connelly  Little, Brown  10/15/2017              7
# 83  David Lagercrantz          Knopf  11/12/2017              7
# 88       Stephen King       Scribner   1/11/2015              7
#
#                               title_case
# 0                  The Girl On The Train
# 1            All The Light We Cannot See
# 2                    Fifty Shades Darker
# 3                        The Nightingale
# 4                               The Help
# ..                                   ...
# 86                              The Drop
# 85             The Wrong Side Of Goodbye
# 84                         The Late Show
# 83  The Girl Who Takes An Eye For An Eye
# 88                               Revival
#
# [99 rows x 5 columns]

# %%
# Rename column title_case to title
nyt_title_new.rename(columns={"title_case": "title"}, inplace=True)
nyt_title_new
# Out:
# C:\Users\ama29\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                author      publisher        date  weeks_on_list  \
# 0       Paula Hawkins      Riverhead   2/19/2017            102
# 1       Anthony Doerr       Scribner    5/7/2017             81
# 2           E L James        Vintage    3/5/2017             66
# 3      Kristin Hannah   St. Martin's  10/29/2017             63
# 4    Kathryn Stockett  Penguin Group    4/8/2012             58
# ..                ...            ...         ...            ...
# 86   Michael Connelly  Little, Brown   3/27/2016              7
# 85   Michael Connelly  Little, Brown   1/15/2017              7
# 84   Michael Connelly  Little, Brown  10/15/2017              7
# 83  David Lagercrantz          Knopf  11/12/2017              7
# 88       Stephen King       Scribner   1/11/2015              7
#
#                                    title
# 0                  The Girl On The Train
# 1            All The Light We Cannot See
# 2                    Fifty Shades Darker
# 3                        The Nightingale
# 4                               The Help
# ..                                   ...
# 86                              The Drop
# 85             The Wrong Side Of Goodbye
# 84                         The Late Show
# 83  The Girl Who Takes An Eye For An Eye
# 88                               Revival
#
# [99 rows x 5 columns]

# %% [markdown]
# ## Google Books API Call
# ### Obtaining ISBN13 numbers for each book
# Documentation:<br>(1) https://developers.google.com/books/docs/v1/reference/volumes
# <br>(2) https://developers.google.com/books/docs/v1/using?authuser=1#auth

# %%
# Define get_url function 
def get_url(title, author):
    url = f"https://www.googleapis.com/books/v1/volumes?q={title}+inauthor:{author}&key={g_api_key}"
    return url

# %%
# Create two lists, one to hold individual book data and another to hold titles that weren't found
googlebooks_data = []
not_found = []

for n in range(len(nyt_title_new)):
    
    print(f"Processing Book {n + 1}: {nyt_title_new.iloc[n]['title']} by {nyt_title_new.iloc[n]['author']}")

    try: 
        single_book = requests.get(get_url(nyt_title_new.iloc[n]["title"], nyt_title_new.iloc[n]["author"])).json()["items"][0]["volumeInfo"]
         
        # Order of identifiers and available identifiers differ for each book
        # If...elif statement used to obtain ISBN_13 specifically
        for x in range(len(single_book["industryIdentifiers"])):
            if single_book["industryIdentifiers"][x]["type"] == "ISBN_13":
                book_isbn = single_book["industryIdentifiers"][x]["identifier"]
            elif single_book["industryIdentifiers"][x]["type"] == "ISBN_10":
                pass
        
        # Find book data values and save in a dictionary 
        g_book_data = {"title": nyt_title_new.iloc[n]["title"],
                       "author": nyt_title_new.iloc[n]['author'],
                       "isbn": book_isbn
                       }

        # Append copy of dictionary to list so values aren't overwritten
        googlebooks_data.append(g_book_data.copy())
        time.sleep(0.35)
        
    except:
        print("Book not found. Skipping...")
        # Add books not found into separate list
        book_no_isbn = {"title": nyt_title_new.iloc[n]['title'],
                        "author": nyt_title_new.iloc[n]['author']
                        }
        not_found.append(book_no_isbn)
    
print("-------------------------------")  
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Processing Book 1: The Girl On The Train by Paula Hawkins
# Processing Book 2: All The Light We Cannot See by Anthony Doerr
# Processing Book 3: Fifty Shades Darker by E L James
# Processing Book 4: The Nightingale by Kristin Hannah
# Processing Book 5: The Help by Kathryn Stockett
# Processing Book 6: A Man Called Ove by Fredrik Backman
# Processing Book 7: Milk And Honey by Rupi Kaur
# Processing Book 8: A Game Of Thrones by George R R Martin
# Processing Book 9: Big Little Lies by Liane Moriarty
# Processing Book 10: Before We Were Yours by Lisa Wingate
# Processing Book 11: The Woman In Cabin 10 by Ruth Ware
# Processing Book 12: The Girl With The Dragon Tattoo by Stieg Larsson
# Processing Book 13: Little Fires Everywhere by Celeste Ng
# Processing Book 14: The Handmaid's Tale by Margaret Atwood
# Processing Book 15: The Whistler by John Grisham
# Processing Book 16: The Longest Ride by Nicholas Sparks
# Processing Book 17: Ready Player One by Ernest Cline
# Processing Book 18: Camino Island by John Grisham
# Processing Book 19: Outlander by Diana Gabaldon
# Processing Book 20: Bared To You by Sylvia Day
# Processing Book 21: Origin by Dan Brown
# Processing Book 22: Lilac Girls by Martha Hall Kelly
# Processing Book 23: The Sun And Her Flowers by Rupi Kaur
# Processing Book 24: 11/22/1963 by Stephen King
# Processing Book 25: Fifty Shades Trilogy by E L James
# Processing Book 26: A Dog's Purpose by W Bruce Cameron
# Processing Book 27: The Marriage Bargain by Jennifer Probst
# Processing Book 28: The Great Alone by Kristin Hannah
# Processing Book 29: The Underground Railroad by Colson Whitehead
# Processing Book 30: Small Great Things by Jodi Picoult
# Processing Book 31: Two By Two by Nicholas Sparks
# Processing Book 32: Go Set A Watchman by Harper Lee
# Processing Book 33: See Me by Nicholas Sparks
# Processing Book 34: The Forgotten by David Baldacci
# Processing Book 35: It by Stephen King
# Processing Book 36: The Woman In The Window by AJ Finn
# Processing Book 37: The Midnight Line by Lee Child
# Processing Book 38: The Rooster Bar by John Grisham
# Processing Book 39: The Last Mile by David Baldacci
# Processing Book 40: Into The Water by Paula Hawkins
# Processing Book 41: The Shack by William P Young
# Processing Book 42: The Silver Linings Playbook by Matthew Quick
# Processing Book 43: Defending Jacob by William Landay
# Processing Book 44: Life Of Pi by Yann Martel
# Processing Book 45: The Mill River Recluse by Darcie Chan
# Processing Book 46: The Fix by David Baldacci
# Processing Book 47: The Escape by David Baldacci
# Processing Book 48: Night School by Lee Child
# Processing Book 49: The Obsession by Nora Roberts
# Processing Book 50: The Nest by Cynthia D'Aprix Sweeney
# Processing Book 51: The Liar by Nora Roberts
# Book not found. Skipping...
# Processing Book 52: No Man's Land by David Baldacci
# Processing Book 53: Cross The Line by James Patterson
# Processing Book 54: The Guilty by David Baldacci
# Processing Book 55: The Girl In The Spider's Web by David Lagercrantz
# Processing Book 56: Kill Alex Cross by James Patterson
# Book not found. Skipping...
# Processing Book 57: The Confession by John Grisham
# Processing Book 58: On The Island by Tracey Garvis-Graves
# Processing Book 59: The Target by David Baldacci
# Processing Book 60: Now You See Her by James Patterson and Michael Ledwidge
# Processing Book 61: Hope To Die by James Patterson
# Processing Book 62: The Best Of Me by Nicholas Sparks
# Book not found. Skipping...
# Processing Book 63: The Hit by David Baldacci
# Processing Book 64: Personal by Lee Child
# Processing Book 65: Darker by EL James
# Processing Book 66: Truly Madly Guilty by Liane Moriarty
# Processing Book 67: A Column Of Fire by Ken Follett
# Processing Book 68: The Choice by Nicholas Sparks
# Processing Book 69: Whiskey Beach by Nora Roberts
# Processing Book 70: The Fifth Witness by Michael Connelly
# Processing Book 71: The Sixth Man by David Baldacci
# Processing Book 72: Smokin' Seventeen by Janet Evanovich
# Processing Book 73: Merry Christmas, Alex Cross by James Patterson
# Processing Book 74: World War Z by Max Brooks
# Processing Book 75: Never Go Back by Lee Child
# Processing Book 76: The Bazaar Of Bad Dreams by Stephen King
# Processing Book 77: The Revenant by Michael Punke
# Processing Book 78: The Girls by Emma Cline
# Processing Book 79: Turbo Twenty-three by Janet Evanovich
# Processing Book 80: End Game by David Baldacci
# Processing Book 81: An American Marriage by Tayari Jones
# Processing Book 82: The Wife Between Us by Greer Hendricks and Sarah Pekkanen
# Processing Book 83: A Week In Winter by Maeve Binchy
# Processing Book 84: Cross My Heart by James Patterson
# Processing Book 85: King And Maxwell by David Baldacci
# Processing Book 86: Mr. Mercedes by Stephen King
# Processing Book 87: Hopeless by Colleen Hoover
# Processing Book 88: Kill Shot by Vince Flynn
# Processing Book 89: Kill Me If You Can by James Patterson and Marshall Karp
# Processing Book 90: Unlucky 13 by James Patterson and Maxine Paetro
# Processing Book 91: The Bet by Rachel Van Dyken
# Processing Book 92: Invisible by James Patterson and David Ellis
# Processing Book 93: Cross Justice by James Patterson
# Processing Book 94: Two Kinds Of Truth by Michael Connelly
# Processing Book 95: The Drop by Michael Connelly
# Processing Book 96: The Wrong Side Of Goodbye by Michael Connelly
# Processing Book 97: The Late Show by Michael Connelly
# Processing Book 98: The Girl Who Takes An Eye For An Eye by David Lagercrantz
# Processing Book 99: Revival by Stephen King
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Chttp://localhost:8888/notebooks/etl_project/etl_project.ipynb#reate dataframe
googlebooks_df = pd.DataFrame(googlebooks_data)
# Check counts for dataframe (96 books found)
googlebooks_df.count()
# Out:
# title     96
# author    96
# isbn      96
# dtype: int64

# %%
# Check to make sure no duplicate ISBNs
googlebooks_df["isbn"].nunique()
# Out:
# 96

# %%
# Create dataframe for books that weren't found
isbndb_other = pd.DataFrame(not_found)
# Check counts for dataframe
isbndb_other
# Out:
#              title           author
# 0         The Liar     Nora Roberts
# 1  Kill Alex Cross  James Patterson
# 2   The Best Of Me  Nicholas Sparks

# %%
# Create new column "isbn"
isbndb_other["isbn"] = pd.Series()
isbndb_other
# Out:
# C:\Users\ama29\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#              title           author  isbn
# 0         The Liar     Nora Roberts   NaN
# 1  Kill Alex Cross  James Patterson   NaN
# 2   The Best Of Me  Nicholas Sparks   NaN

# %% [markdown]
# ## ISBNdb API call
# ### Finding ISBN13 numbers for books not found with Google API

# %%
# Define get_url function 
def get_url(title, author):
    url = f"https://api2.isbndb.com/books/{title}{author}"
    return url

h = {"Authorization": isbn_api_key}

# %%
# Go through each book and look up its ISBN13
for n in range(len(isbndb_other)):
    
    print(f"Searching for {isbndb_other.iloc[n]['title']} by {isbndb_other.iloc[n]['author']}")

    try: 
        single_book = requests.get(get_url(isbndb_other.iloc[n]["title"], isbndb_other.iloc[n]["author"]), headers=h).json()
        single_book_isbn = single_book["books"][0]["isbn13"]
        isbndb_other.iloc[n, isbndb_other.columns.get_loc("isbn")] = single_book_isbn
        time.sleep(0.3)

    except:
        print("Book not found. Skipping...")
             
print("-------------------------------")  
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Searching for The Liar by Nora Roberts
# Searching for Kill Alex Cross by James Patterson
# Searching for The Best Of Me by Nicholas Sparks
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# View updated table
isbndb_other
# Out:
#              title           author           isbn
# 0         The Liar     Nora Roberts  9781607060673
# 1  Kill Alex Cross  James Patterson  9781611132168
# 2   The Best Of Me  Nicholas Sparks  9780751542981

# %%
# Append isbndb_other dataframe to googlebooks_df
googlebooks_df = googlebooks_df.append(isbndb_other)
googlebooks_df
# Out:
#                                    title             author           isbn
# 0                  The Girl On The Train      Paula Hawkins  9780698185395
# 1            All The Light We Cannot See      Anthony Doerr  9781476746586
# 2                    Fifty Shades Darker          E L James  9780525431886
# 3                        The Nightingale     Kristin Hannah  9781628995015
# 4                               The Help   Kathryn Stockett  9781440697661
# ..                                   ...                ...            ...
# 94  The Girl Who Takes An Eye For An Eye  David Lagercrantz  9780451494337
# 95                               Revival       Stephen King  9781476770383
# 0                               The Liar       Nora Roberts  9781607060673
# 1                        Kill Alex Cross    James Patterson  9781611132168
# 2                         The Best Of Me    Nicholas Sparks  9780751542981
#
# [99 rows x 3 columns]

# %%
# Reset index
googlebooks_df.reset_index(drop=True, inplace=True)
googlebooks_df
# Out:
#                                    title             author           isbn
# 0                  The Girl On The Train      Paula Hawkins  9780698185395
# 1            All The Light We Cannot See      Anthony Doerr  9781476746586
# 2                    Fifty Shades Darker          E L James  9780525431886
# 3                        The Nightingale     Kristin Hannah  9781628995015
# 4                               The Help   Kathryn Stockett  9781440697661
# ..                                   ...                ...            ...
# 94  The Girl Who Takes An Eye For An Eye  David Lagercrantz  9780451494337
# 95                               Revival       Stephen King  9781476770383
# 96                              The Liar       Nora Roberts  9781607060673
# 97                       Kill Alex Cross    James Patterson  9781611132168
# 98                        The Best Of Me    Nicholas Sparks  9780751542981
#
# [99 rows x 3 columns]

# %% [markdown]
# #### Please keep in mind that the ISBNs obtained via API are not foolproof. In this case, "The Liar" by Nora Roberts and "The Target" by David Baldacci were both found to have incorrect ISBNs, which were manually corrected.

# %%
# Manually change ISBN of "The Liar" by Nora Roberts
googlebooks_df["isbn"].loc[googlebooks_df["title"] == "The Liar"] = 9780399170867
# Manually change ISBN of "The Target" by David Baldacci
googlebooks_df["isbn"].loc[googlebooks_df["title"] == "The Target"] = 9781455521203

# %%
# Confirm modification of one
googlebooks_df["isbn"].loc[googlebooks_df["title"] == "The Liar"]
# Out:
# 96    9780399170867
# Name: isbn, dtype: object

# %%
# Confirm no null values in isbn column
googlebooks_df["isbn"].isna().sum()
# Out:
# 0

# %%
# Join googlebooks_df on "title" and "author" with nyt_title_new for isbn column
nyt_merge_df = pd.merge(googlebooks_df, nyt_title_new, on=["title", "author"])
nyt_merge_df
# Out:
#                                    title             author           isbn  \
# 0                  The Girl On The Train      Paula Hawkins  9780698185395
# 1            All The Light We Cannot See      Anthony Doerr  9781476746586
# 2                    Fifty Shades Darker          E L James  9780525431886
# 3                        The Nightingale     Kristin Hannah  9781628995015
# 4                               The Help   Kathryn Stockett  9781440697661
# ..                                   ...                ...            ...
# 94  The Girl Who Takes An Eye For An Eye  David Lagercrantz  9780451494337
# 95                               Revival       Stephen King  9781476770383
# 96                              The Liar       Nora Roberts  9780399170867
# 97                       Kill Alex Cross    James Patterson  9781611132168
# 98                        The Best Of Me    Nicholas Sparks  9780751542981
#
#                   publisher        date  weeks_on_list
# 0                 Riverhead   2/19/2017            102
# 1                  Scribner    5/7/2017             81
# 2                   Vintage    3/5/2017             66
# 3              St. Martin's  10/29/2017             63
# 4             Penguin Group    4/8/2012             58
# ..                      ...         ...            ...
# 94                    Knopf  11/12/2017              7
# 95                 Scribner   1/11/2015              7
# 96                   Putnam   4/10/2016             10
# 97  Little, Brown & Company    2/5/2012             10
# 98            Grand Central  11/16/2014              9
#
# [99 rows x 6 columns]

# %%
# Sort descending by weeks on the list
nyt_merge_df.sort_values(by=["weeks_on_list"], ascending=False, inplace=True)
nyt_merge_df.reset_index(drop=True, inplace=True)
nyt_merge_df
# Out:
#                           title            author           isbn  \
# 0         The Girl On The Train     Paula Hawkins  9780698185395
# 1   All The Light We Cannot See     Anthony Doerr  9781476746586
# 2           Fifty Shades Darker         E L James  9780525431886
# 3               The Nightingale    Kristin Hannah  9781628995015
# 4                      The Help  Kathryn Stockett  9781440697661
# ..                          ...               ...            ...
# 94                     Hopeless    Colleen Hoover  9781481251884
# 95                 Mr. Mercedes      Stephen King  9781476754451
# 96             King And Maxwell    David Baldacci  9781455521227
# 97             A Week In Winter      Maeve Binchy  9780385350082
# 98               Cross My Heart   James Patterson  9780316210928
#
#                      publisher        date  weeks_on_list
# 0                    Riverhead   2/19/2017            102
# 1                     Scribner    5/7/2017             81
# 2                      Vintage    3/5/2017             66
# 3                 St. Martin's  10/29/2017             63
# 4                Penguin Group    4/8/2012             58
# ..                         ...         ...            ...
# 94              Colleen Hoover   2/24/2013              7
# 95                    Scribner    8/3/2014              7
# 96               Grand Central   1/19/2014              7
# 97  Knopf Doubleday Publishing   4/14/2013              7
# 98               Little, Brown    2/2/2014              7
#
# [99 rows x 6 columns]

# %% [markdown]
# ## Goodreads API
# #### Call with ISBN13 to retrieve further data (rating, review numbers, etc.)
# Documentation: https://www.goodreads.com/api/index#book.show_by_isbn

# %%
# Define get_url_gr function 
def get_url_gr(isbn):
    url = f"https://www.goodreads.com/book/review_counts.json?isbns={isbn}&key={goodreads_api_key}"
    return url

# %%
# Go through each book and find its average rating, total ratings count, and total text reviews count
goodreads_data = []

for n in range(len(nyt_merge_df)):
    
    print(f"Processing Book {n + 1}: {nyt_merge_df.iloc[n]['title']} by {nyt_merge_df.iloc[n]['author']}")
    
    try: 
        gr_book_json = requests.get(get_url_gr(nyt_merge_df.iloc[n]["isbn"])).json()["books"][0]
        # Find book data values and save in a dictionary 
        gr_book_data = {"isbn": nyt_merge_df.iloc[n]["isbn"],
                        "avg_rating": gr_book_json["average_rating"],
                        "ratings_count": gr_book_json["work_ratings_count"],
                        "reviews_count": gr_book_json["work_text_reviews_count"]
                       }
        # Append copy of dictionary to list so values aren't overwritten
        goodreads_data.append(gr_book_data.copy())
        # Goodreads API guidelines: no more than one call per second
        time.sleep(1.5)

    except:
        print("Book not found. Skipping...")

print("-------------------------------")  
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Processing Book 1: The Girl On The Train by Paula Hawkins
# Processing Book 2: All The Light We Cannot See by Anthony Doerr
# Processing Book 3: Fifty Shades Darker by E L James
# Processing Book 4: The Nightingale by Kristin Hannah
# Processing Book 5: The Help by Kathryn Stockett
# Processing Book 6: A Man Called Ove by Fredrik Backman
# Processing Book 7: Milk And Honey by Rupi Kaur
# Processing Book 8: A Game Of Thrones by George R R Martin
# Processing Book 9: Big Little Lies by Liane Moriarty
# Processing Book 10: Before We Were Yours by Lisa Wingate
# Processing Book 11: The Woman In Cabin 10 by Ruth Ware
# Processing Book 12: Little Fires Everywhere by Celeste Ng
# Processing Book 13: The Girl With The Dragon Tattoo by Stieg Larsson
# Processing Book 14: The Handmaid's Tale by Margaret Atwood
# Processing Book 15: The Whistler by John Grisham
# Processing Book 16: The Longest Ride by Nicholas Sparks
# Processing Book 17: Ready Player One by Ernest Cline
# Processing Book 18: Camino Island by John Grisham
# Processing Book 19: Outlander by Diana Gabaldon
# Processing Book 20: Bared To You by Sylvia Day
# Processing Book 21: Origin by Dan Brown
# Processing Book 22: Lilac Girls by Martha Hall Kelly
# Processing Book 23: The Sun And Her Flowers by Rupi Kaur
# Processing Book 24: Fifty Shades Trilogy by E L James
# Processing Book 25: 11/22/1963 by Stephen King
# Processing Book 26: A Dog's Purpose by W Bruce Cameron
# Processing Book 27: The Marriage Bargain by Jennifer Probst
# Processing Book 28: The Great Alone by Kristin Hannah
# Processing Book 29: The Underground Railroad by Colson Whitehead
# Processing Book 30: Small Great Things by Jodi Picoult
# Processing Book 31: Two By Two by Nicholas Sparks
# Processing Book 32: Go Set A Watchman by Harper Lee
# Processing Book 33: See Me by Nicholas Sparks
# Processing Book 34: The Forgotten by David Baldacci
# Processing Book 35: It by Stephen King
# Processing Book 36: The Woman In The Window by AJ Finn
# Processing Book 37: The Last Mile by David Baldacci
# Processing Book 38: The Midnight Line by Lee Child
# Processing Book 39: The Rooster Bar by John Grisham
# Processing Book 40: Into The Water by Paula Hawkins
# Processing Book 41: The Shack by William P Young
# Processing Book 42: The Silver Linings Playbook by Matthew Quick
# Processing Book 43: Defending Jacob by William Landay
# Processing Book 44: Life Of Pi by Yann Martel
# Processing Book 45: The Mill River Recluse by Darcie Chan
# Processing Book 46: The Fix by David Baldacci
# Processing Book 47: The Escape by David Baldacci
# Processing Book 48: The Obsession by Nora Roberts
# Processing Book 49: The Nest by Cynthia D'Aprix Sweeney
# Processing Book 50: Night School by Lee Child
# Processing Book 51: Cross The Line by James Patterson
# Processing Book 52: The Guilty by David Baldacci
# Processing Book 53: The Girl In The Spider's Web by David Lagercrantz
# Processing Book 54: The Confession by John Grisham
# Processing Book 55: Kill Alex Cross by James Patterson
# Processing Book 56: The Liar by Nora Roberts
# Processing Book 57: No Man's Land by David Baldacci
# Processing Book 58: Darker by EL James
# Processing Book 59: The Choice by Nicholas Sparks
# Processing Book 60: A Column Of Fire by Ken Follett
# Processing Book 61: Truly Madly Guilty by Liane Moriarty
# Processing Book 62: The Best Of Me by Nicholas Sparks
# Processing Book 63: Personal by Lee Child
# Processing Book 64: Hope To Die by James Patterson
# Processing Book 65: On The Island by Tracey Garvis-Graves
# Processing Book 66: The Target by David Baldacci
# Processing Book 67: The Hit by David Baldacci
# Processing Book 68: Now You See Her by James Patterson and Michael Ledwidge
# Processing Book 69: The Revenant by Michael Punke
# Processing Book 70: The Wife Between Us by Greer Hendricks and Sarah Pekkanen
# Processing Book 71: An American Marriage by Tayari Jones
# Processing Book 72: End Game by David Baldacci
# Processing Book 73: Turbo Twenty-three by Janet Evanovich
# Processing Book 74: The Girls by Emma Cline
# Processing Book 75: The Bazaar Of Bad Dreams by Stephen King
# Processing Book 76: World War Z by Max Brooks
# Processing Book 77: Merry Christmas, Alex Cross by James Patterson
# Processing Book 78: Smokin' Seventeen by Janet Evanovich
# Processing Book 79: Whiskey Beach by Nora Roberts
# Processing Book 80: The Sixth Man by David Baldacci
# Processing Book 81: The Fifth Witness by Michael Connelly
# Processing Book 82: Never Go Back by Lee Child
# Processing Book 83: Cross Justice by James Patterson
# Processing Book 84: Revival by Stephen King
# Processing Book 85: The Girl Who Takes An Eye For An Eye by David Lagercrantz
# Processing Book 86: The Late Show by Michael Connelly
# Processing Book 87: The Wrong Side Of Goodbye by Michael Connelly
# Processing Book 88: The Drop by Michael Connelly
# Processing Book 89: Two Kinds Of Truth by Michael Connelly
# Processing Book 90: Unlucky 13 by James Patterson and Maxine Paetro
# Processing Book 91: Invisible by James Patterson and David Ellis
# Processing Book 92: The Bet by Rachel Van Dyken
# Processing Book 93: Kill Me If You Can by James Patterson and Marshall Karp
# Processing Book 94: Kill Shot by Vince Flynn
# Processing Book 95: Hopeless by Colleen Hoover
# Processing Book 96: Mr. Mercedes by Stephen King
# Processing Book 97: King And Maxwell by David Baldacci
# Processing Book 98: A Week In Winter by Maeve Binchy
# Processing Book 99: Cross My Heart by James Patterson
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Create dataframe
goodreads_df = pd.DataFrame(goodreads_data)
# Check counts to ensure all books in dataframe
goodreads_df.count()
# Out:
# isbn             99
# avg_rating       99
# ratings_count    99
# reviews_count    99
# dtype: int64

# %%
# View final table
goodreads_df
# Out:
#              isbn avg_rating  ratings_count  reviews_count
# 0   9780698185395       3.92        2078549         109889
# 1   9781476746586       4.33        1003524          74999
# 2   9780525431886       3.84         736764          29076
# 3   9781628995015       4.58         678152          63280
# 4   9781440697661       4.47        2138643          84467
# ..            ...        ...            ...            ...
# 94  9781481251884       4.29         264516          21462
# 95  9781476754451       3.97         235432          16602
# 96  9781455521227       4.10          28509           1898
# 97  9780385350082       3.83          42860           5408
# 98  9780316210928       4.08          20671           1878
#
# [99 rows x 4 columns]

# %%
# Export goodreads_df as .csv file
goodreads_df.to_csv("output_data/goodreads.csv", encoding='utf-8', index = False)

# %% [markdown]
# ## Postgresql

# %% [markdown]
# ### Connect to local database (books_db)

# %%
rds_conn_string = f"{username}:{password}@localhost:5432/books_db"
engine = create_engine(f'postgresql://{rds_conn_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['nyt_weeks', 'goodreads_ratings']

# %% [markdown]
# ### Use Pandas to load dataframes into database

# %%
nyt_merge_df.to_sql(name='nyt_weeks', con=engine, if_exists='append', index=False)

# %%
goodreads_df.to_sql(name='goodreads_ratings', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the New York Times Bestsellers table

# %%
pd.read_sql_query('select * from nyt_weeks', con=engine).head()
# Out:
#                          title            author           isbn  \
# 0        The Girl On The Train     Paula Hawkins  9780698185395
# 1  All The Light We Cannot See     Anthony Doerr  9781476746586
# 2          Fifty Shades Darker         E L James  9780525431886
# 3              The Nightingale    Kristin Hannah  9781628995015
# 4                     The Help  Kathryn Stockett  9781440697661
#
#        publisher        date  weeks_on_list
# 0      Riverhead  2017-02-19            102
# 1       Scribner  2017-05-07             81
# 2        Vintage  2017-03-05             66
# 3   St. Martin's  2017-10-29             63
# 4  Penguin Group  2012-04-08             58

# %% [markdown]
# ### Confirm data has been added by querying the Goodreads table

# %%
pd.read_sql_query('select * from goodreads_ratings', con=engine).head()
# Out:
#             isbn  avg_rating  ratings_count  reviews_count
# 0  9780698185395        3.92        2078549         109889
# 1  9781476746586        4.33        1003524          74999
# 2  9780525431886        3.84         736764          29076
# 3  9781628995015        4.58         678152          63280
# 4  9781440697661        4.47        2138643          84467
